# %% [markdown]
# # 访问 Ollama 嵌入模型

# %%
from langchain_ollama import OllamaEmbeddings

# %%
model = OllamaEmbeddings(model="qwen3-embedding:4b")

# %%
# 不用invoke stream
# embed_query、embed_documents
print(model.embed_query("我喜欢你"))
print(model.embed_documents(["我喜欢你", "我稀饭你", "晚上吃啥"]))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 不用invoke stream
#       2 # embed_query、embed_documents
# ----> 3 print(model.embed_query("我喜欢你"))
#       4 print(model.embed_documents(["我喜欢你", "我稀饭你", "晚上吃啥"]))
#
# File D:\anaconda3\Lib\site-packages\langchain_ollama\embeddings.py:307, in OllamaEmbeddings.embed_query(self, text)
#     305 def embed_query(self, text: str) -> list[float]:
#     306     """Embed query text."""
# --> 307     return self.embed_documents([text])[0]
#
# File D:\anaconda3\Lib\site-packages\langchain_ollama\embeddings.py:301, in OllamaEmbeddings.embed_documents(self, texts)
#     296     msg = (
#     297         "Ollama client is not initialized. "
#     298         "Please ensure Ollama is running and the model is loaded."
#     299     )
#     300     raise ValueError(msg)
# --> 301 return self._client.embed(
#     302     self.model, texts, options=self._default_params, keep_alive=self.keep_alive
#     303 )["embeddings"]
#
# File D:\anaconda3\Lib\site-packages\ollama\_client.py:393, in Client.embed(self, model, input, truncate, options, keep_alive, dimensions)
#     384 def embed(
#     385   self,
#     386   model: str = '',
#    (...)    391   dimensions: Optional[int] = None,
#     392 ) -> EmbedResponse:
# --> 393   return self._request(
#     394     EmbedResponse,
#     395     'POST',
#     396     '/api/embed',
#     397     json=EmbedRequest(
#     398       model=model,
#     399       input=input,
#     400       truncate=truncate,
#     401       options=options,
#     402       keep_alive=keep_alive,
#     403       dimensions=dimensions,
#     404     ).model_dump(exclude_none=True),
#     405   )
#
# File D:\anaconda3\Lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File D:\anaconda3\Lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model "qwen3-embedding:4b" not found, try pulling it first (status code: 404)
