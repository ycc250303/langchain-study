# %% [markdown]
# # 模板类的format和invoke方法

# %% [markdown]
# - PromptTemplate、FewShotPromptTemplate、ChatPromptTemplate 都有 `invoke` 和 `format`方法
#
# ![image.png](attachment:e081ddd1-37af-40c5-9329-b2a344d8db0c.png)
#
# - `format` 和 `invoke` 的区别
#
# ![image.png](attachment:8e0b6b99-0976-4a44-8f39-0ab1882f8e78.png)

# %%
from langchain_core.prompts import PromptTemplate

# %%
template = PromptTemplate.from_template("我的邻居是：{lastname}，最喜欢：{hobby}")

# %%
res = template.format(lastname="张大明", hobby="钓鱼")
print(res, type(res))
# Out:
# 我的邻居是：张大明，最喜欢：钓鱼 <class 'str'>

# %%
# 传字典
res2 = template.invoke({"lastname": "周杰轮", "hobby": "唱歌"})
print(res2, type(res2))
# Out:
# text='我的邻居是：周杰轮，最喜欢：唱歌' <class 'langchain_core.prompt_values.StringPromptValue'>
