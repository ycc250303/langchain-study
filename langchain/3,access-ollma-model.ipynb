# %% [markdown]
# # LangChain 访问 Ollma 模型

# %%
from langchain_ollama import OllamaLLM

# %%
# 记得下载好模型，并且打开 Ollama
model = OllamaLLM(model="qwen3:4b")

# 查看任务管理器的 GPU 状态
res = model.invoke(input="你是谁呀能做什么？")

# %%
print(res)
# Out:
# 你好！我是**通义千问**，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。你可以叫我**Qwen**。
#
# ### 我能做什么？
# 1. **回答问题**
#    - 无论是科学、文化、生活常识，还是冷门知识，我都能帮你解答。
#    - 例：*“为什么天空是蓝色的？”*、*“如何快速学编程？”*
#
# 2. **创作文字**
#    - 写故事、写公文、写邮件、写剧本、写诗歌、写歌词……
#    - 例：*“请写一个关于未来城市的短篇科幻故事”*
#
# 3. **编程辅助**
#    - 帮你写代码、调试程序、解释技术问题。
#    - 例：*“用Python写一个计算斐波那契数列的函数”*
#
# 4. **逻辑推理 & 数学计算**
#    - 解题、做数学题、逻辑谜题，甚至帮你规划行程。
#    - 例：*“求1到100的质数之和”*
#
# 5. **多语言支持**
#    - 中文、英文、德语、法语、西班牙语等百种语言切换，无障碍交流。
#
# 6. **表达观点**
#    - 你可以问我“你觉得AI会取代人类吗？”，我会结合数据和逻辑给出分析。
#
# 7. **玩游戏**
#    - 从猜谜、成语接龙到策略游戏，我都能陪你玩！
#
# ---
#
# **举个栗子🌰**：
# 你问：“帮我写一封给朋友的生日祝福邮件”，我就能立刻生成一段温暖又得体的文字。
# 你问：“怎么用Python画个简单的图形？”，我就能一步步指导你写代码。
#
# **试试看吧！** 有什么需要，直接告诉我～ 😊
