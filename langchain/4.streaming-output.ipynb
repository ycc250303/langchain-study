# %% [markdown]
# # 流式输出

# %% [markdown]
# - `invoke` 方法：一次性获取所有结果
# - `stream` 方法：逐段返回结果

# %%
from langchain_community.llms.tongyi import Tongyi

llm = Tongyi(model="qwen-max")

# invoke 方法改为 stream 方法
res = llm.stream("帮我讲个笑话")

# %%
# 逐段返回结果
# res 为迭代器
for chunk in res:
    print(chunk, end="", flush=True)
# Out:
# 好的，接下来我给你讲一个笑话：
#
# 为什么电脑经常生病？
#
# 因为它的窗户（Windows）总是开着！
