# %% [markdown]
# # JSONLoader

# %%
# !pip install jq
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting jq
#   Downloading https://mirrors.aliyun.com/pypi/packages/cd/16/4697abf6c1d92e8297e07c3fba6d400b5a9c71780a24072480d9076451d7/jq-1.11.0-cp313-cp313-win_amd64.whl (409 kB)
# Installing collected packages: jq
# Successfully installed jq-1.11.0

# %% [markdown]
# ![image.png](attachment:7cc2d52d-9e69-4711-8012-a59a4532a5c9.png)

# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path="./data/stu_json_lines.json",
    jq_schema=".",
    text_content=False,     # 告知JSONLoader 我抽取的内容不是字符串
    json_lines=True         # 告知JSONLoader 这是一个JSONLines文件（每一行都是一个独立的标准JSON）
)

# %%
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': 'D:\\GitHub\\ycc\\langchain-study\\langchain\\data\\stu_json_lines.json', 'seq_num': 1}, page_content='{"name": "\\u5468\\u6770\\u8f6e", "age": 11, "gender": "\\u7537"}'), Document(metadata={'source': 'D:\\GitHub\\ycc\\langchain-study\\langchain\\data\\stu_json_lines.json', 'seq_num': 2}, page_content='{"name": "\\u8521\\u4f9d\\u4e34", "age": 12, "gender": "\\u5973"}'), Document(metadata={'source': 'D:\\GitHub\\ycc\\langchain-study\\langchain\\data\\stu_json_lines.json', 'seq_num': 3}, page_content='{"name": "\\u738b\\u529b\\u9e3f", "age": 11, "gender": "\\u7537"}')]
